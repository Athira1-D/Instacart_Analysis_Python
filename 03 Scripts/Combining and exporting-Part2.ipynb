# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\User\Desktop\Career foundry task'

# %%
df_orders_products_combined = pd.read_pickle(os.path.join(path, 'Python', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_orders_products_combined .shape
# Out:
# (32434489, 12)

# %%
df_prods = pd.read_csv(os.path.join(path, 'Python', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id evaluation_set  order_number  \
# 0           0   2539329        1          prior             1
# 1           0   2539329        1          prior             1
# 2           0   2539329        1          prior             1
# 3           0   2539329        1          prior             1
# 4           0   2539329        1          prior             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_orders_products_combined = df_orders_products_combined.drop(columns = ['_merge'])

# %%
df_merged = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id evaluation_set  order_number  \
# 0             0   2539329        1          prior             1
# 1             1   2398795        1          prior             2
# 2             2    473747        1          prior             3
# 3             3   2254736        1          prior             4
# 4             4    431534        1          prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
#    add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
df_merged = df_merged.drop(columns = ['Unnamed: 0_y','Unnamed: 0_x'])

# %%
df_merged.head()
# Out:
#    order_id  user_id evaluation_set  order_number  orders_day_of_week  \
# 0   2539329        1          prior             1                   2
# 1   2398795        1          prior             2                   3
# 2    473747        1          prior             3                   3
# 3   2254736        1          prior             4                   4
# 4    431534        1          prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged.to_pickle(os.path.join(path, 'Python','Prepared Data', 'orders_products_merged.pkl'))
